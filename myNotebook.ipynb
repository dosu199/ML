# %%
a = 10
b = 5
c = a + b

# %%
print(c)
# Out:
# 15

# %%
1 + 1
# Out:
# 2

# %%
## My markdown

# %% [markdown]
# ## Heart disease project

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 3.0.3

# %%
df = pd.read_csv("heart-disease.csv")

# %% [markdown]
# ## This table respresent pacients data

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %% [markdown]
# ![_](6-step-ml-framework.png)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BE3D-656C
#
#  Directory of C:\Users\Suad Muhic\Desktop\sample_project_1\env
#
# 16/06/2026  10:32    <DIR>          .
# 15/06/2026  11:34    <DIR>          ..
# 16/06/2026  10:05    <DIR>          .ipynb_checkpoints
# 16/06/2026  10:30           332,025 6-step-ml-framework.png
# 15/06/2026  11:40    <DIR>          etc
# 16/06/2026  10:20            11,328 heart-disease.csv
# 15/06/2026  11:34    <DIR>          Include
# 15/06/2026  11:34    <DIR>          Lib
# 16/06/2026  10:32            21,531 myNotebook.ipynb
# 15/06/2026  11:34               348 pyvenv.cfg
# 15/06/2026  11:42    <DIR>          Scripts
# 15/06/2026  11:42    <DIR>          share
# 15/06/2026  11:53             1,638 Untitled.ipynb
# 16/06/2026  10:05               617 Untitled1.ipynb
#                6 File(s)        367,487 bytes
#                8 Dir(s)  206,564,630,528 bytes free
